# %%
import pandas as pd

compteur= pd.read_csv("C:/Users/Administrateur/Downloads/comptage-velo-donnees-compteurs.csv",engine='python',error_bad_lines=False,delimiter=";")

# %%
compteur.tail()
# Out:
#        Identifiant du compteur          Nom du compteur  \
# 870354            100063173-SC  74 Boulevard Ornano S-N
# 870355            100063173-SC  74 Boulevard Ornano S-N
# 870356            100063173-SC  74 Boulevard Ornano S-N
# 870357            100063173-SC  74 Boulevard Ornano S-N
# 870358            100063173-SC  74 Boulevard Ornano S-N
#
#         Identifiant du site de comptage  Nom du site de comptage  \
# 870354                      100063173.0  74 Boulevard Ornano S-N
# 870355                      100063173.0  74 Boulevard Ornano S-N
# 870356                      100063173.0  74 Boulevard Ornano S-N
# 870357                      100063173.0  74 Boulevard Ornano S-N
# 870358                      100063173.0  74 Boulevard Ornano S-N
#
#         Comptage horaire  Date et heure de comptage  \
# 870354              99.0  2020-11-18T07:00:00+01:00
# 870355              84.0  2020-11-18T10:00:00+01:00
# 870356             103.0  2020-11-18T15:00:00+01:00
# ...

# %%
compteur['Nom du site de comptage'].isnull()
# Out:
# 0          True
# 1          True
# 2          True
# 3          True
# 4          True
#           ...
# 870354    False
# 870355    False
# 870356    False
# 870357    False
# 870358    False
# Name: Nom du site de comptage, Length: 870359, dtype: bool

# %%
compteur['Nom du compteur'].isnull()
# Out:
# 0         False
# 1         False
# 2         False
# 3         False
# 4         False
#           ...
# 870354    False
# 870355    False
# 870356    False
# 870357    False
# 870358    False
# Name: Nom du compteur, Length: 870359, dtype: bool

# %%
#select column nom du site de comptage without Null value

# %%
compteur["diff"] = compteur.apply(lambda x : x["Nom du compteur"] if x["Nom du compteur"] != x["Nom du site de comptage"],axis=1)
# Out:
#   File "<ipython-input-31-8f8da3d31b01>", line 1
#     compteur["diff"] = compteur.apply(lambda x : x["Nom du compteur"] if x["Nom du compteur"] != x["Nom du site de comptage"],axis=1)
#                                                                                                                              ^
# SyntaxError: invalid syntax

# %%
import numpy as np
#compteur['diff'] = compteur[[compteur["Nom du compteur"]!= compteur["Nom du site de comptage"]]]
compteur['diff']=np.where(compteur["Nom du compteur"] == compteur["Nom du site de comptage"], True, False)
compteur
# Out:
#        Identifiant du compteur                    Nom du compteur  \
# 0                          NaN  97 avenue Denfert Rochereau SO-NE
# 1                          NaN  97 avenue Denfert Rochereau SO-NE
# 2                          NaN  97 avenue Denfert Rochereau SO-NE
# 3                          NaN  97 avenue Denfert Rochereau SO-NE
# 4                          NaN  97 avenue Denfert Rochereau SO-NE
# ...                        ...                                ...
# 870354            100063173-SC            74 Boulevard Ornano S-N
# 870355            100063173-SC            74 Boulevard Ornano S-N
# 870356            100063173-SC            74 Boulevard Ornano S-N
# 870357            100063173-SC            74 Boulevard Ornano S-N
# 870358            100063173-SC            74 Boulevard Ornano S-N
#
#         Identifiant du site de comptage  Nom du site de comptage  \
# 0                                   NaN                      NaN
# ...

# %%
compteur[compteur["diff"]=="False"]
# Out:
# Empty DataFrame
# Columns: [Identifiant du compteur, Nom du compteur, Identifiant du site de comptage, Nom du site de comptage, Comptage horaire, Date et heure de comptage, Date d'installation du site de comptage, Lien vers photo du site de comptage, Coordonn̩es g̩ographiques, diff]
# Index: []

# %%
print(compteur[compteur.isnull()])
compteur=compteur.dropna(subset=["Comptage horaire"])
# Out:
#        Nom du compteur Nom du site de comptage  Comptage horaire  \
# 0                  NaN                     NaN               NaN
# 1                  NaN                     NaN               NaN
# 2                  NaN                     NaN               NaN
# 3                  NaN                     NaN               NaN
# 4                  NaN                     NaN               NaN
# ...                ...                     ...               ...
# 870354             NaN                     NaN               NaN
# 870355             NaN                     NaN               NaN
# 870356             NaN                     NaN               NaN
# 870357             NaN                     NaN               NaN
# 870358             NaN                     NaN               NaN
#
#        Date et heure de comptage Date d'installation du site de comptage  \
# 0                            NaN                                     NaN
# ...

# %%
print(compteur_full[compteur_full.isnull()])
# Out:
#        Nom du compteur Nom du site de comptage  Comptage horaire  \
# 0                  NaN                     NaN               NaN
# 1                  NaN                     NaN               NaN
# 2                  NaN                     NaN               NaN
# 3                  NaN                     NaN               NaN
# 4                  NaN                     NaN               NaN
# ...                ...                     ...               ...
# 870354             NaN                     NaN               NaN
# 870355             NaN                     NaN               NaN
# 870356             NaN                     NaN               NaN
# 870357             NaN                     NaN               NaN
# 870358             NaN                     NaN               NaN
#
#        Date et heure de comptage Date d'installation du site de comptage  \
# 0                            NaN                                     NaN
# ...

# %%
compteur["x"]=compteur["Coordonn̩es g̩ographiques"].apply(lambda x:x.split(",")[0])
compteur["y"]=compteur["Coordonn̩es g̩ographiques"].apply(lambda x:x.split(",")[1])
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-16-b8d79b72cb31> in <module>
# ----> 1 compteur["x"]=compteur["Coordonn̩es g̩ographiques"].apply(lambda x:x.split(",")[0])
#       2 compteur["y"]=compteur["Coordonn̩es g̩ographiques"].apply(lambda x:x.split(",")[1])
#
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\core\series.py in apply(self, func, convert_dtype, args, **kwds)
#    3846             else:
#    3847                 values = self.astype(object).values
# -> 3848                 mapped = lib.map_infer(values, f, convert=convert_dtype)
#    3849
#    3850         if len(mapped) and isinstance(mapped[0], Series):
#
# pandas\_libs\lib.pyx in pandas._libs.lib.map_infer()
#
# <ipython-input-16-b8d79b72cb31> in <lambda>(x)
# ----> 1 compteur["x"]=compteur["Coordonn̩es g̩ographiques"].apply(lambda x:x.split(",")[0])
# ...
